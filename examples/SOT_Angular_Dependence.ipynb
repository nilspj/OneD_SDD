755396,-3.50503597122302,-3.52230215827338,-3.56546762589928,-3.54820143884892,-3.57194244604317,-3.61079136690647,-3.61510791366906,-3.6410071942446,-3.69280575539568,-3.73597122302158,-3.75755395683453,-3.78776978417266,-3.8136690647482,-3.86978417266187,-3.86978417266187,-3.91942446043165,-3.97553956834532,-4.10935251798561,-4.12877697841727,-4.19784172661871,-4.21726618705036,-4.27769784172662,-4.34028776978417,-4.38992805755396,-4.39640287769784])

# %%
 # Fit for Pt/Co
ints1 = np.array([0.0,3e-9,3.6e-9])
rho = 36e-8
I = 1.136e-3
A= (5.2e-9*1e-6)
E1 = np.array([rho*I/A,0,0]) 
Pt = sdd.HM_BulkParameters(De = 0.001, sigma = 7e6, l_sf = 1.4e-9, theta_SHAy = 0.19)
Co = sdd.FM_BulkParameters(De = 0.001, sigma = 5e6, l_sf = 38e-9, l_J = 1.2e-9, l_phi = 1.8e-9, m = np.array([0,0,1]), beta_S = 0.36, beta_D = 0.36)
Pt_Co_int = sdd.RashbaSpinMixing_InterfaceParameters(u0 = 0.05921851, uEx = 0.27844199, uR =0.21664024, uD = 0.0, kF =16e9)
# Out:
# Reading quadrature points and weights

# %%
# Fit for Ta/CoFeB
ints2 = np.array([0.0,3e-9,3.9e-9])
rho = 184e-8
I = 500e-6
A =(5.9e-9*1e-6)
E2 = np.array([rho*I/A,0,0]) 
Ta = sdd.HM_BulkParameters( De = 0.001, sigma = 0.5e6, l_sf =  1.9e-9, theta_SHAy = -0.15)
CoFeB = sdd.FM_BulkParameters( De = 0.001, sigma = 3.33e6, l_sf = 12e-9, l_J = 1.2e-9, l_phi = 2e-9, m = np.array([0,0,1]), beta_S = 0.56, beta_D = 0.56)
Ta_CoFeB_int = sdd.RashbaSpinMixing_InterfaceParameters(u0 =0.0746735, uEx = 1.55931818, uR =  -1.17935625, uD = 0.0, kF =1.5e10)
# Out:
# Reading quadrature points and weights

# %%
N = 100
theta = np.linspace(0,65,N)
Ts_1 = np.zeros((2*N,3))
Ts_2 = np.zeros((2*N,3))
mag_0 = np.asarray([[np.sin(th*np.pi/180),0,np.cos(th*np.pi/180)] for th in theta])
mag_90 = np.asarray([[0,np.sin(th*np.pi/180),np.cos(th*np.pi/180)] for th in theta])
mag = np.concatenate((mag_0,mag_90))
for i in range(mag.shape[0]):
    Co.m = mag[i]
    bulk_params = [Pt, Co]
    int_params = [Pt_Co_int]
    LinSys = sdd.SDD_1D_solver(E1, ints1, bulk_params, int_params)
    LinSys.solve_linear_system()
    Ts_1[i,:] = LinSys.get_total_spin_torque()[1,:]

    CoFeB.m = mag[i]
    bulk_params = [Ta, CoFeB]
    int_params = [Ta_CoFeB_int]
    LinSys = sdd.SDD_1D_solver(E2, ints2, bulk_params, int_params)
    LinSys.solve_linear_system()
    Ts_2[i,:] = LinSys.get_total_spin_torque()[1,:]
# Out:
# Quadrature computation time:  0.08412861824035645
# Quadrature computation time:  0.07885527610778809
# Quadrature computation time:  0.07898569107055664
# Quadrature computation time:  0.07868123054504395
# Quadrature computation time:  0.0782930850982666
# Quadrature computation time:  0.08020591735839844
# Quadrature computation time:  0.07863450050354004
# Quadrature computation time:  0.07816505432128906
# Quadrature computation time:  0.07837462425231934
# Quadrature computation time:  0.07830357551574707
# Quadrature computation time:  0.07854866981506348
# Quadrature computation time:  0.07867932319641113
# Quadrature computation time:  0.0788109302520752
# Quadrature computation time:  0.07911801338195801
# Quadrature computation time:  0.07938766479492188
# Quadrature computation time:  0.07899093627929688
# Quadrature computation time:  0.07918882369995117
# Quadrature computation time:  0.08061623573303223
# Quadrature computation time:  0.0815880298614502
# ...

# %%
conv1 = -1/(1.760859708e+11*0.6e6*0.6e-9) 
conv2 = -1/(1.760859708e+11*0.81e6*0.9e-9)
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, sharey= False, sharex=True, figsize=(9,9))
for ax in [ax1,ax2,ax3,ax4]:
    ax.set_box_aspect(1)

ax1.set_title(r'Field-like$/\cos(\theta)$, $\phi = 90^\circ$',fontsize=14)
ax1.plot(theta,( Ts_1[N:, 0])*conv1*1e3/np.cos(theta*np.pi/180),c='r',ls='-',lw=3.0, label=r'Computed')
ax1.set_ylabel(r"Torque [mT]",fontsize=14, labelpad=11)
ax1.text( 0.35, 0.1, 'Pt/Co', fontsize=14, transform=ax1.transAxes, va='top')

ax2.set_title('Damping-like, $\phi = 0^\circ$',fontsize=14)
ax2.plot(theta, ( Ts_1[:N, 1])*conv1*1e3,ls='-',c='r',lw=3.0, label=r'Computed')
ax2.text( 0.35, 0.1, 'Pt/Co', fontsize=14, transform=ax2.transAxes, va='top')

ax3.plot(theta,( Ts_2[N:, 0])*conv2*1e3/np.cos(theta*np.pi/180),c='r',ls='-',lw=3.0, label=r'Computed')
ax3.set_xlabel(r'Polar angle $\theta$[$^\circ$]',fontsize=14)
ax3.set_ylabel(r"Torque [mT]",fontsize=14)
ax3.text( 0.3, 0.1, 'Ta/CoFeB', fontsize=14, transform=ax3.transAxes, va='top')

ax4.plot(theta, ( Ts_2[:N, 1])*conv2*1e3,ls='-',c='r',lw=3.0, label=r'Computed')
ax4.set_xlabel(r'Polar angle $\theta$[$^\circ$]',fontsize=14)

ax1.scatter(np.arcsin(np.sqrt(G_fl_x))*180/np.pi,(G_fl_y),marker="o",color = "k",s=20,label="Measured",zorder=5)
ax2.scatter(G_dl_x,(G_dl_y),marker="o",color = "k",s=20,label="Measured",zorder=5)
ax3.scatter(T_fl_x,(T_fl_y),marker="o",color = "k",s=20,label="Measured",zorder=5)
ax4.scatter(T_dl_x,(T_dl_y),marker="o",color = "k",s=20,label="Measured",zorder=5)

ax1.legend(frameon=False,fancybox=False, framealpha=1, fontsize=12, shadow=True, borderpad=0.4)

ax4.text( 0.3, 0.1, 'Ta/CoFeB', fontsize=14, transform=ax4.transAxes, va='top')
for ax in [ax1, ax2, ax3, ax4]:
    ax.set_xticks([0, 10, 20, 30, 40, 50, 60])
ax1.set_ylim(11,20)
ax1.set_xlim(5,60)
ax2.set_ylim(18.5,20.5)
ax2.set_xlim(5,60)
ax3.set_ylim(-17.5,-5)
ax3.set_xlim(5,60)
ax4.set_ylim(-4.5,-2.75)
ax4.set_xlim(5,60)

plt.tight_layout()
plt.show()
